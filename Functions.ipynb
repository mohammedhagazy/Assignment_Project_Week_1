# %% [markdown]
# **Built-in Function**

# %%
x = 30 
type(x)
# Out:
# int

# %%
y = str(x)
print(y)
type(y)
# Out:
# 30
# str

# %%
y_int = int(y)
print(y_int)
type(y_int)
# Out:
# 30
# int

# %% [markdown]
# **Doctstring**
# is used

# %%
# A function to calculate My Rough shoping costs
def shopping_estimate():                                             #Function Defination/Header
    """This function adds the costs od item in my shopping lists     #Function Documentation
    and retun the total estimated cost."""

    total_estimate = 500 + 600                                       #Function Body
    print(total_estimate)                                            #Function Boday

shopping_estimate()
# Out:
# 1100

# %% [markdown]
# **Function Parameters/Argument**

# %%
def happiness_purchase_estimate(ahmed_mango, daniel_fords, yasmin_gold,
                                gloria_vacay, ngesas_gun, rebort_friedchiken, moses_ps5):
    total_price_estimate = ahmed_mango + daniel_fords + yasmin_gold + gloria_vacay + ngesas_gun + rebort_friedchiken + moses_ps5
    print(total_price_estimate)

happiness_purchase_estimate(100, 13000000, 975000,15000000, 100000, 2000, 80000)
# Out:
# 29157100

# %%
# passing an altimate number of arguments to function to a function using *args*
def happiness_purchase_estimated(**happinessPrice):
    """This function add the costs of items in my happiness purchase list"""

    total_price_estimate = sum(happinessPrice.values())

    print(total_price_estimate)
happiness_purchase_estimated(ahmed_mango=100, daniel_fords=13000000, yasmin_gold=975000, gloria_vacay=150000,
                               ngesas_gun=100000, roberto_friedchicken=2000,james_tx=9500000, kai_defender=22990000, 
                               norman_apartment=40000000,erick_stocks = 29841.85, dennis_jersey=12947.30,
                               christana_range=7000000)
# Out:
# 93759889.14999999

# %% [markdown]
# **Outputing  multiple valyes**

# %%
# passing an altimate number of arguments to function to a function using *args*
count = 0
def happiness_purchase_estimated(**happinessPrice):
    """This function add the costs of items in my happiness purchase list"""

    total_price_estimate = sum(happinessPrice.values())
    print(type(total_price_estimate))
    for key in happinessPrice.keys():
        global count 
        count += 1
        total_students = count
    print(total_students)
    print(total_price_estimate)

happiness_purchase_estimated(ahmed_mango=100, daniel_fords=13000000, yasmin_gold=975000, gloria_vacay=150000,
                               ngesas_gun=100000, roberto_friedchicken=2000,james_tx=9500000, kai_defender=22990000, 
                               norman_apartment=40000000,erick_stocks = 29841.85, dennis_jersey=12947.30,
                               christana_range=7000000)
# Out:
# <class 'float'>
# 12
# 93759889.14999999

# %% [markdown]
# **Returning Multiple values**

# %%
def raise_values(a, b):
    """Raise the value a and b to power 2 and 3 respectavely and return the  results"""

    raised_to_two = a ** 2
    raised_to_three = b ** 3
    print(type(raised_to_two))
    print(type(raised_to_two))

    answer = (raised_to_two, raised_to_three)
    print(type(answer))
    return(answer)
raise_values(30,50)
# Out:
# <class 'int'>
# <class 'int'>
# <class 'tuple'>
# (900, 125000)

# %%
API_key = "0ba05323cfff0f9a36aee6c38ed48fcd"

# %%
# importing the request laibrary to make API calls 
import requests

# %%
def get_weather(city):
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        main = data['main']
        temperature = main['temp']
        weather_description = data['weather'][0]['description']
        return f"The temperature in {city} is {temperature}°C with {weather_description}."
    else:
        return "I couldn't retrieve the weather information."

# %%
get_weather("nairobi")
# Out:
# 'The temperature in nairobi is 14.93°C with broken clouds.'

# %%
import requests

# Free API, no key needed: https://frankfurter.app
def convert_currency(amount, from_currency, to_currency):
    url = f"https://api.frankfurter.app/latest?amount={amount}&from={from_currency}&to={to_currency}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        converted_amount = data["rates"][to_currency]
        return f"{amount} {from_currency} is equal to {converted_amount} {to_currency}."
    else:
        return "I couldn't retrieve the exchange rate information."


if __name__ == "__main__":
    print(convert_currency(100, "USD", "KES"))
# Out:
# I couldn't retrieve the exchange rate information.

# %%
import requests
 
# Free, no API key needed, supports KES and 160+ other currencies: https://open.er-api.com
def convert_currency(amount, from_currency, to_currency):
    url = f"https://open.er-api.com/v6/latest/{from_currency}"
    response = requests.get(url)
 
    if response.status_code == 200:
        data = response.json()
        rate = data["rates"][to_currency]
        converted_amount = amount * rate
        return f"{amount} {from_currency} is equal to {round(converted_amount, 2)} {to_currency}."
    else:
        return "I couldn't retrieve the exchange rate information."
 
 
print(convert_currency(150, "USD", "SOS"))
# Out:
# 150 USD is equal to 85657.37 SOS.

# %% [markdown]
# **Lambda Function**

# %%
# A function that takes two parametres a and b raise a to the power b
def raisea2b(a, b):
     """" A function that takes two parametrs a and b and raise a to the power of b"""
     raised_to_b = a ** b
     print(raised_to_b)
     
raisea2b(20, 3)
# Out:
# 8000

# %%
raisex2y_short = lambda x, y: x ** y
print(raisex2y_short(20,3))
# Out:
# 8000

# %% [markdown]
# **Anonymoous Function**

# %%
nums = [10, 30, 60, 15]
squared_nums =map(lambda num : num ** 2, nums)
print(squared_nums)

# %%
print(tuple(squared_nums))
# Out:
# (100, 900, 3600, 225)

# %% [markdown]
# **Regular Expresion**

# %% [markdown]
# #### Sring menipulation
# - eg: is replacing and finding specific sub string

# %% [markdown]
# #### Sring formation
# - eg: interpulating a sting into  a taplate

# %% [markdown]
# **why is all important**
# - clean or datasets and preparing them for **Natural Language Processings (NPL)** Takes list sentiment Analysis,
# Text Mining etc
# - Process  Email comtents to feed to a ML Agorithm that checks wether and Email sperm or not
# - Parse and Exctract text specific Data from a website thhat you can use to build a DB(Web Scapping)

# %%
myString = "Amazing Learning Experiance so far"
myString2= "here at zindua school"

# %%
# Finding the length of s tring
len(myString)
# Out:
# 34

# %% [markdown]
# **String Operations**
# - These include .lower() , .upper() , .capitlize

# %%
complete_sentence = myString + " " + myString2

# %%
# Splitting s string into a list  of substrings
complete_sentence.split(sep=" ", maxsplit = 2)
# Out:
# ['Amazing', 'Learning', 'Experiance so far here at zindua school']

# %%
# Splitting a string into a list of substring using an Escape Character
my_new_sentence = "My favourite Artists are: \n1. Caoster ojwang\n2. Being\n3. Njarae"
print(my_new_sentence)
# Out:
# My favourite Artists are:
# 1. Caoster ojwang
# 2. Being
# 3. Njarae

# %%
# Using the split() method
my_new_sentence.split(sep="\n", maxsplit = 3)
# Out:
# ['My favourite Artists are: ', '1. Caoster ojwang', '2. Being', '3. Njarae']

# %%
# '.join(iterable)'

# %% [markdown]
# **Finding and Replacing String**
# - String.find(substring, start, end(exclusive just line in lindexing))

# %%
my_name = "My name is Ahmed and not Ahmeed"

# %%
# Finding a substring in a string 
my_name.find("Ahmed", 0, 11)
# Out:
# -1

# %%
name_str = "The speaker name is Ahmeed"

# %%
name_str.replace("Ahmeed", "Ahmed")
# Out:
# 'The speaker name is Ahmed'

# %% [markdown]
# **Reqular Expresions**
# - A Regular Expression is a string Containing a combination of normal characters and special characters that describes patterns to find text or positions within a text

# %%
import re

# %%
movie_str = "I really enjoyed watching the Movie '#1Spid7er Man: Brand New Day and I would recommend it"

# %%
# Use Regular Expression to only find the movie name in the string 'movie_str' above

"""
The Syntax of Find all is :
're.findall(r'regex_pattern', string_to_search)'
"""
re.findall(r"#1Spid\d", movie_str)

#movie_name = re.search(r"Movie #[0-9]+([a-zA-Z0-9 ]+), movie_str)
#if movie_name:
#print(movie_name.group(1))
# Out:
# ['#1Spid7']

# %%
| Character  | Meaning  | Code Example  | What is Coden Does |
|------|------|------|------|
| | Digit |
# Out:
#   Cell In[172], line 1
#     | Character  | Meaning  | Code Example  | What is Coden Does |
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Simple \D Metacharacter**

# %%
winners= "The winners for the Hackathon are User6, User8"

re.findall(r'User\d', winners)
# Out:
# ['User6', 'User8']

# %% [markdown]
# **Simple \D Metacharacter**

# %%
winners2= "The winners for the Hackathon are Userk, Userl and  User8"

re.findall(r'User\D', winners2)
# Out:
# ['Userk', 'Userl']

# %% [markdown]
# **Sample \w Metacharacter**

# %%
winners3= "The winners for the Hackathon are User9, UserJ and  UserPQ"

re.findall(r'User\w' and r'\w+', winners3)
# Out:
# ['The',
#  'winners',
#  'for',
#  'the',
#  'Hackathon',
#  'are',
#  'User9',
#  'UserJ',
#  'and',
#  'UserPQ']
