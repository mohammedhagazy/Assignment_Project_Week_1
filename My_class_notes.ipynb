# %%
found_guilty = True

# %% [markdown]
# Arithmetic Operators

# %% [markdown]
# ### conditional statement

# %%
. if true perform a task 
           otherwise do nothing
# Out:
#   Cell In[9], line 1
#     . if true perform a task
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# |Keyword|Function|Use|
# |------|------|------|
# |'if'| Check if Condition|is met |Frist in the workflow|
# |'elif'| else check if another Condition is met | after 'if' |
# |'else'|Else perform this action | After 'elif' or 'if' |

# %%
rand_list = [ "Anita", 20, True, 90.45, 360]
type(rand_list)
# Out:
# list

# %%
grades = [10, 30, 40, 40 ]

# %%
grades[2]
# Out:
# 40

# %%
grades[1]
# Out:
# 30

# %%
grades[-3]
# Out:
# 30

# %% [markdown]
#  Accessing Multiple Elements in list

# %%
# i want to acces and print 20,11, 30 from the list below
Prices = [10, 20, 11, 30, 40]

# %%
Prices = [10, 20, 11, 30, 40]
print (prices[1:4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 Prices = [10, 20, 11, 30, 40]
# ----> 2 print (prices[1:4])
#
# NameError: name 'prices' is not defined

# %%
print(Prices[1], Prices[2], Prices[3])
# Out:
# 20 11 30

# %%
Prices[1:4]
# Out:
# [20, 11, 30]

# %%
print(Prices[1:4])
# Out:
# [20, 11, 30]

# %%
result = Prices[0:5:2]
print(result)
# Out:
# [10, 11, 40]

# %%
result = Prices[::2]
print(result)
# Out:
# [10, 11, 40]

# %%
flight_numbers = {"KQ100": "LHR" , "KQ113": "NBO", 
                  "KQ414": "EBB", "KQ508": "ACC",
                  "KQ886": "BKK", "KQ760": "JNB"}

# %%
# check if there is a key for flight to CPT KQ792
if "KQ792" and "KQ2" in flight_number:
    print("kenyan Airweys has a flight CPT and New York")

else :
    # add that flight to dictionary and then print it
    flight_numbers ["KQ792"] = "CPT"
    # print the value is QK2
    flight_number["KQ2"] = "JFK"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # check if there is a key for flight to CPT KQ792
# ----> 2 if "KQ792" and "KQ2" in flight_number:
#       3     print("kenyan Airweys has a flight CPT and New York")
#       4
#       5 else :
#
# NameError: name 'flight_number' is not defined
